# %%
# Import dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt

# %%
# Import csv (includes MovieData.csv and API data)
combined_df = pd.read_csv("Resources/api_merge_df.csv")
combined_df
# Out:
#                     movie_name      Country Release Date  IMDB Rating  \
# 0       Madea's Family Reunion          USA  24 Feb 2006          5.2
# 1                       Krrish        India  23 Jun 2006          6.4
# 2             End of the Spear          USA  20 Jan 2006          6.8
# 3     A Prairie Home Companion          USA  09 Jun 2006          6.7
# 4                      Saw III  Canada, USA  27 Oct 2006          6.2
# ...                        ...          ...          ...          ...
# 1821                    Widows      UK, USA  16 Nov 2018          8.0
# 1822            Instant Family          USA  16 Nov 2018          7.2
# 1823                  The Mule  USA, Canada  14 Dec 2018          7.3
# 1824                  Creed II          USA  21 Nov 2018          7.3
# 1825         Bohemian Rhapsody      UK, USA  02 Nov 2018          6.3
#
#       Metascore TomatoMeter  production_budget  domestic_box_office  \
# ...

# %%
# Grouping df by genre
grouped_genre = combined_df.groupby(["genre"])

# Summing totals 
sum_genre = grouped_genre.sum()
sum_genre
# Out:
#                      IMDB Rating  Metascore  production_budget  \
# genre
# Action                    1901.1    14986.0        26038700000
# Adventure                 1960.5    15995.0        29770700000
# Black Comedy               146.9     1124.0          726000000
# Comedy                    1842.2    14392.0         9693100000
# Concert/Performance         34.3      333.0           68000000
# Documentary                 44.3      405.0          231000000
# Drama                     2928.0    23416.0        13878350000
# Horror                     608.0     4583.0         2455550000
# Musical                    154.9     1332.0         1802200000
# Romantic Comedy            467.5     3822.0         2371320000
# Thriller/Suspense         1467.1    11428.0         9334000000
# Western                     92.8      689.0          888000000
#
#                      domestic_box_office  international_box_office  \
# genre
# ...

# %%
sum_genre['genre']=sum_genre.index
sum_genre
# Out:
#                      IMDB Rating  Metascore  production_budget  \
# genre
# Action                    1901.1    14986.0        26038700000
# Adventure                 1960.5    15995.0        29770700000
# Black Comedy               146.9     1124.0          726000000
# Comedy                    1842.2    14392.0         9693100000
# Concert/Performance         34.3      333.0           68000000
# Documentary                 44.3      405.0          231000000
# Drama                     2928.0    23416.0        13878350000
# Horror                     608.0     4583.0         2455550000
# Musical                    154.9     1332.0         1802200000
# Romantic Comedy            467.5     3822.0         2371320000
# Thriller/Suspense         1467.1    11428.0         9334000000
# Western                     92.8      689.0          888000000
#
#                      domestic_box_office  international_box_office  \
# genre
# ...

# %%
# Bar chart analysis comparing domestic and international box office per genre
x_axis = np.arange(len(sum_genre))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(30,10))
plt.bar(x_axis, sum_genre["domestic_box_office"], color='b', alpha=1, align="center")
plt.xticks(tick_locations, sum_genre["genre"], rotation="horizontal")
plt.title('Domestic box office revenue per genre')
plt.ylabel('Revenue in billions of U.S. dollars')
plt.xlabel('Genres')
# Out:
# Text(0.5, 0, 'Genres')

# %%
# Bar chart analysis comparing domestic and international box office per genre
x_axis = np.arange(len(sum_genre))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(30,10))
plt.bar(x_axis, sum_genre["international_box_office"], color='r', alpha=1, align="center")
plt.xticks(tick_locations, sum_genre["genre"], rotation="horizontal")
plt.title('International box office revenue per genre')
plt.ylabel('Revenue in billions of U.S. dollars')
plt.xlabel('Genres')
# Out:
# Text(0.5, 0, 'Genres')

# %%
# Bar chart showing total box office revenue per genre
x_axis = np.arange(len(sum_genre))
tick_locations = [value for value in x_axis]

plt.figure(figsize=(30,10))
plt.bar(x_axis, sum_genre["Total Box Office"], color='g', alpha=1, align="center")
plt.xticks(tick_locations, sum_genre["genre"], rotation="horizontal")
plt.title('Total box office revenue per genre')
plt.ylabel('Revenue in billions of U.S. dollars')
plt.xlabel('Genres')
# Out:
# Text(0.5, 0, 'Genres')

# %%
# DISREGARD, THIS WAS WHAT I HAD IN THE BEGINNING USING 3 NEW CSV FILES I CREATED TO HELP CLEAN THE DATA IN EXCEL:
# Make a reference to the InternationalBoxOfficeTotals.csv file path
csv_path = "Resources/InternationalBoxOfficeTotals.csv"

# Import the file as a Dataframe
InternationalBoxOfficeTotals_df=pd.read_csv(csv_path, encoding="utf-8")
InternationalBoxOfficeTotals_df.head()
# Out:
#   Row Labels  Sum of international box office
# 0     Action               $57,000,902,013.00
# 1  Adventure               $64,466,697,986.00
# 2     Comedy               $12,094,316,721.00
# 3      Drama               $19,424,530,234.00
# 4     Horror                $5,343,559,889.00

# %%
# Make a reference to the DomesticAndInternationalBoxOfficeTotals.csv file path
csv_path = "Resources/DomesticAndInternationalBoxOfficeTotals.csv"

# Import the file as a Dataframe
DomesticAndInternationalBoxOfficeTotals_df=pd.read_csv(csv_path, encoding="utf-8")
DomesticAndInternationalBoxOfficeTotals_df.head()
# Out:
#       Genres Domestic & International totals
# 0     Action             $87,120,941,636.00
# 1  Adventure            $102,107,263,302.00
# 2     Comedy             $28,158,114,541.00
# 3      Drama             $36,199,506,185.00
# 4     Horror             $10,060,158,410.00

# %%
# Bar graph for Domestic Box Office Totals
plt.bar(x=DomesticBoxOfficeTotals_df['Row Labels'],
       height=DomesticBoxOfficeTotals_df['Sum of domestic box office'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sum of domestic box office'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-200aae92bfd8> in <module>
# ...

# %%
# Bar graph for International Box Office Totals
x_axis = np.arange(len(InternationalBoxOfficeTotals_df))
