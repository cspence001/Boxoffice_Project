# %%
#dependencies
# Dependencies
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
#import csv (includes MovieData.csv and API data)
timedf = pd.read_csv("Resources/time_df.csv")
timedf
# Out:
#                     movie_name      Country    Released  IMDB Rating  \
# 0       Madea's Family Reunion          USA  24-02-2006          5.2
# 1                       Krrish        India  23-06-2006          6.4
# 2             End of the Spear          USA  20-01-2006          6.8
# 3     A Prairie Home Companion          USA  09-06-2006          6.7
# 4                      Saw III  Canada, USA  27-10-2006          6.2
# ...                        ...          ...         ...          ...
# 1821                    Widows      UK, USA  16-11-2018          8.0
# 1822            Instant Family          USA  16-11-2018          7.2
# 1823                  The Mule  USA, Canada  14-12-2018          7.3
# 1824                  Creed II          USA  21-11-2018          7.3
# 1825         Bohemian Rhapsody      UK, USA  02-11-2018          6.3
#
#       Metascore TomatoMeter  production_budget  domestic_box_office  \
# 0          45.0         26%           10000000             63257940
# ...

# %%
sorted(timedf["Year"].unique())
# Out:
# [1915,
#  1946,
#  1956,
#  1959,
#  1964,
#  1967,
#  1972,
#  1976,
#  1977,
#  1978,
#  1980,
#  1981,
#  1982,
#  1984,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1995,
#  1996,
#  1997,
#  1999,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019]
