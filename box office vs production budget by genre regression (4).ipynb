# %%
import pandas as pd
import matplotlib.pyplot as plt

a = pd.read_csv("/Users/alexandergoldstein/Downloads/api_merge_df.csv")
file = pd.DataFrame(a)

b = file['domestic_box_office'] + file['international_box_office']
BoxOffice = pd.DataFrame(b)
file['BoxOffice'] = BoxOffice

c = file['BoxOffice'] / file['production_budget']
ROI = pd.DataFrame(c)
file['ROI'] = ROI

DomesticFilms = file[file.rating != "Not Rated"]
InternationalFilms = file[file.rating == "Not Rated"]

# %%
#listing genres

Films = file.dropna()
d = Films.drop_duplicates(['genre'])
print(d['genre'])
# Out:
# 0                   Comedy
# 1                   Action
# 2                    Drama
# 4                   Horror
# 6             Black Comedy
# 8        Thriller/Suspense
# 23                 Musical
# 27               Adventure
# 63         Romantic Comedy
# 258                Western
# 346    Concert/Performance
# 503            Documentary
# Name: genre, dtype: object

# %%
#creating unique dataframe for each genre

e = Films

f = e[e.genre == "Action"]
g = e[e.genre == "Comedy"]
h = e[e.genre == "Drama"]
i = e[e.genre == "Horror"]
j = e[e.genre == "Adventure"]
k = e[e.genre == "Black Comedy"]
l = e[e.genre == "Thriller/Suspense"]
m = e[e.genre == "Romantic Comedy"]
n = e[e.genre == "Western"]
o = e[e.genre == "Musical"]
p = e[e.genre == "Concert/Performance"]
q = e[e.genre == "Documentary"]

r = e[e.rating == "G"]
s = e[e.rating == "PG"]
t = e[e.rating == "PG-13"]
u = e[e.rating == "R"]

print(len(f), len(g), len(h), len(i), len(j), len(k), len(l), len(m), len(n), len(o), len(p), len(q))
print(len(r), len(s), len(t), len(u))

#black comedy, western, musical, concert/performance and documentary genres have deficient (<30) quantity of 
#observations; statistical analysis of their box office performance given predictive factors is unreliable
# Out:
# 283 282 419 95 291 22 218 72 13 23 5 6
# 28 282 710 676

# %%
#now for the regression analysis

import numpy as np
     
model1 = np.corrcoef(f['production_budget'], f['BoxOffice'])[0, 1]
model2 = np.corrcoef(g['production_budget'], g['BoxOffice'])[0, 1]
model3 = np.corrcoef(h['production_budget'], h['BoxOffice'])[0, 1]
model4 = np.corrcoef(i['production_budget'], i['BoxOffice'])[0, 1]
model5 = np.corrcoef(j['production_budget'], j['BoxOffice'])[0, 1]
model6 = np.corrcoef(k['production_budget'], k['BoxOffice'])[0, 1]
model7 = np.corrcoef(l['production_budget'], l['BoxOffice'])[0, 1]
model8 = np.corrcoef(m['production_budget'], m['BoxOffice'])[0, 1]
model9 = np.corrcoef(n['production_budget'], n['BoxOffice'])[0, 1]
model10 = np.corrcoef(o['production_budget'], o['BoxOffice'])[0, 1]
model11 = np.corrcoef(p['production_budget'], p['BoxOffice'])[0, 1]
model12 = np.corrcoef(q['production_budget'], q['BoxOffice'])[0, 1]

box = [model1, model2, model3, model4, model5, model6, model7, model8, model9, model10, model11, model12]

for model in box:
    print(model)
    
#returns pearson's correlation coefficient
# Out:
# 0.8197965942747568
# 0.4931418824390307
# 0.520596113088565
# 0.4056432004806375
# 0.7031787187973277
# 0.6590942952226213
# 0.7252668599344823
# 0.5326900155969354
# 0.5820456670159309
# 0.6420637546901916
# -0.40374917907948654
# 0.45646956542236655

# %%
#plots

plt.scatter(f['production_budget'], f['BoxOffice'])
plt.title('Action')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
plt.scatter(g['production_budget'], g['BoxOffice'])
plt.title('Comedy')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
plt.scatter(h['production_budget'], h['BoxOffice'])
plt.title('Drama')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
plt.scatter(i['production_budget'], i['BoxOffice'])
plt.title('Horror')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
plt.scatter(k['production_budget'], k['BoxOffice'])
plt.title('Black Comedy')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
plt.scatter(j['production_budget'], j['BoxOffice'])
plt.title('Adventure')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
plt.scatter(l['production_budget'], l['BoxOffice'])
plt.title('Thriller/Suspense')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
plt.scatter(m['production_budget'], m['BoxOffice'])
plt.title('Romantic Comedy')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
plt.scatter(n['production_budget'], n['BoxOffice'])
plt.title('Western')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
plt.scatter(o['production_budget'], o['BoxOffice'])
plt.title('Musical')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
plt.scatter(p['production_budget'], p['BoxOffice'])
plt.title('Concert/Performance')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
plt.scatter(q['production_budget'], q['BoxOffice'])
plt.title('Documentary')
plt.xlabel("budget")
plt.ylabel("box office")
plt.show()

# %%
#as you can see, not only from the pearson correlation coefficients but the scatter plots as well, that
#there is a strong correlation between production budget and box office revenue. However, 5 genres: Black Comedy, 
#Western, Musical, Concert/Performance and Documentary, the relationship was less clear, due to the scant number of 
#films in each of those genres. For the more popular genres, there was also a concentration of films with a relatively
#lower budget and box office take.
